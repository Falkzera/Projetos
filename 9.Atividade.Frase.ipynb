# %%
frase = 'O Python é uma linguagem de programação multiparadigma. Python foi criado por Guido Van Rossum.'


i = 0
while i < len(frase):
    letra_atual = frase[i]
    
    print(letra_atual)
    i += 1
# Out:
# O
#
# P
# y
# t
# h
# o
# n
#
# é
#
# u
# m
# a
#
# l
# i
# n
# g
# u
# a
# g
# e
# m
#
# d
# e
#
# p
# r
# o
# g
# r
# a
# m
# a
# ç
# ã
# o
#
# m
# u
# l
# t
# i
# p
# a
# r
# a
# d
# i
# g
# m
# a
# .
#
# P
# y
# t
# h
# o
# n
#
# f
# o
# i
#
# c
# r
# i
# a
# d
# o
#
# p
# o
# r
#
# G
# u
# i
# d
# o
#
# V
# a
# n
#
# R
# o
# s
# s
# u
# m
# .
